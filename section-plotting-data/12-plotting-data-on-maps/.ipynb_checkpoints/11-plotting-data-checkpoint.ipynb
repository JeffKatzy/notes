# %% [markdown]
# # Plotting Restaurants

# %% [markdown]
# ### Introduction

# %% [markdown]
# A nice restaurant in New York can get pretty pricy.  But we think we can eat our way to a good deal, if we just find the right buffet.  In this lesson, we'll make a map of the various buffets in New York with data pulled from Yelp.

# %%
import requests

# %%
response = requests.get('https://api.foursquare.com/v2/venues/explore/?near=Chelsea%20NYC&venuePhotos=1&section=food&client_id=YZQZP1Q2HEJWMD5ZVBMIQD3VSZC1W4BQCCQTVFEPJWNHL0RK&client_secret=ORHPL2VKKHUTB3KTJVDTB4D20AXBRCFKWVL12EPQNJNDFYBX&v=20131124')

# %%
headers = {"Authorization": "Bearer V-w71bBGGOyWbXNZuBEwIQkhzVmZIe9AExAO_Wh4yXkV3JhZijUT5fFyjAec5oOXUVBBUl8V3e6SbhiQZM9yBKTmFEPdJXQnXbF705rRPc4e3EV4ORH1RquZcTWvWnYx"}

import requests
endpoint = "https://api.yelp.com/v3/businesses/search?location=nyc&categories=buffets"
businesses = requests.get(endpoint, headers=headers).json()
yelp_businesses = businesses['businesses']

# %%
mapped_businesses = []
for business in yelp_businesses:
    mapped_businesses.append(dict((k, business.get(k, None)) for k in ('name', 'review_count', 'price', 'rating', 'categories', 'coordinates')))

# %%
small_businesses = []
for business in mapped_businesses:
    business['category'] = business['categories'][0]['title']
    del business['categories']
    small_businesses.append(business)

# %%
small_businesses
# Out:
# [{'name': 'Dhaba Indian Cuisine',
#   'review_count': 1441,
#   'price': '$$',
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.742364, 'longitude': -73.982813},
#   'category': 'Indian'},
#  {'name': 'Villa Brazil Cafe Grill',
#   'review_count': 316,
#   'price': '$$',
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7552896059395,
#    'longitude': -73.9180071651936},
#   'category': 'Brazilian'},
#  {'name': 'Chola',
#   'review_count': 560,
#   'price': '$$',
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76026, 'longitude': -73.96576},
#   'category': 'Indian'},
#  {'name': 'Darbar Fine Indian Cuisine',
#   'review_count': 519,
#   'price': '$$',
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75358, 'longitude': -73.97348},
#   'category': 'Indian'},
#  {'name': 'Akino',
#   'review_count': 366,
#   'price': '$$',
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7411784, 'longitude': -73.8814239},
#   'category': 'Sushi Bars'},
# ...

# %%
import json
with open('data.txt', 'w') as outfile:  
    json.dump(small_businesses, outfile)

# %%
cleaned_restaurants = None
with open('data.txt') as jsonfile:
    cleaned_restaurants = json.load(jsonfile)

# %%
cleaned_restaurants
# Out:
# [{'name': 'Dhaba Indian Cuisine',
#   'review_count': 1441,
#   'price': '$$',
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.742364, 'longitude': -73.982813},
#   'category': 'Indian'},
#  {'name': 'Villa Brazil Cafe Grill',
#   'review_count': 316,
#   'price': '$$',
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7552896059395,
#    'longitude': -73.9180071651936},
#   'category': 'Brazilian'},
#  {'name': 'Chola',
#   'review_count': 560,
#   'price': '$$',
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76026, 'longitude': -73.96576},
#   'category': 'Indian'},
#  {'name': 'Darbar Fine Indian Cuisine',
#   'review_count': 519,
#   'price': '$$',
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75358, 'longitude': -73.97348},
#   'category': 'Indian'},
#  {'name': 'Akino',
#   'review_count': 366,
#   'price': '$$',
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7411784, 'longitude': -73.8814239},
#   'category': 'Sushi Bars'},
# ...

# %%
items[0]['venue'].keys()
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'categories', 'verified', 'stats', 'beenHere', 'photos', 'hereNow'])

# %%
from yelp_restaurants import restaurants

# %%
restaurants
# Out:
# [{'name': 'Dhaba Indian Cuisine',
#   'review_count': 1441,
#   'price': '$$',
#   'rating': 3.5,
#   'category': 'Indian'},
#  {'name': 'Villa Brazil Cafe Grill',
#   'review_count': 316,
#   'price': '$$',
#   'rating': 4.5,
#   'category': 'Brazilian'},
#  {'name': 'Chola',
#   'review_count': 560,
#   'price': '$$',
#   'rating': 4.0,
#   'category': 'Indian'},
#  {'name': 'Darbar Fine Indian Cuisine',
#   'review_count': 519,
#   'price': '$$',
#   'rating': 4.0,
#   'category': 'Indian'},
#  {'name': 'Akino',
#   'review_count': 366,
#   'price': '$$',
#   'rating': 4.5,
#   'category': 'Sushi Bars'},
#  {'name': "Let's Meat",
#   'review_count': 562,
#   'price': '$$$',
#   'rating': 4.0,
#   'category': 'Korean'},
#  {'name': 'Darbar Grill',
#   'review_count': 497,
#   'price': '$$',
#   'rating': 4.0,
#   'category': 'Indian'},
#  {'name': 'Lan Ting Hotpot',
#   'review_count': 182,
#   'price': '$$',
#   'rating': 4.5,
#   'category': 'Hot Pot'},
#  {'name': 'Namaste',
# ...
